# %% [markdown]
# ### COMP 4447
# ### Final Project
# ### Robert McLellan & Jonathan Yun

# %% [markdown]
# ## Motivation
# •	Dataset and motivation slide (1 points)
# - How/why the dataset was collected and a description of the metadata of your dataset.

# %% [markdown]
# Each year the World Health Organization (WHO) provides recommendations of the makeup of seasonal flu vaccines based on regions. The WHO informs these recommendations based on data from the WHO Global Influenza Surveillance and Response System (GISRS), a global system of public health institutions that share surveillance data of circulating viruses. For the Northern hemisphere recommendations tend to be made in February ahead of the flu season, while recommendations for the Southern hemisphere are made in September. The most recent recommendations for the Northern hemisphere were released on February 24th, 2023.

# %% [markdown]
# ## Research Question
# •	Actual task definition/research question (2 points)
# - What real-world problem are you trying to solve? What are the input and output of your analysis?

# %% [markdown]
# Research Question: We aim to give a recommendation on the makeup of the annual flu vaccine by analyzing influenza data provided by the WHO. We hope our recommedation aligns with the WHO recommendation, and will explore why it does/does not.
# We will be looking to investigate influenza data and determine which strands of the flu are most prevalent. We well then look into the vaccination of the influenza and based of our analysis will determine which vaccines should be recommended.

# %% [markdown]
# ## Literature Review
# •	Literature review (2 points)
# -	What other work has been done in this area, and how is your work novel compared to others?

# %% [markdown]
# Lit review

# %% [markdown]
# ## Data Cleaning
# •	Quality of cleaning (6 points, 2 points each)
#
# - Data cleaning and type conversion activity. Please share anything unusual you faced during this activity.
# - What did you do about missing values and why? Handling missing values properly is very important.
# - New feature/attribute creation and data summary statistics and interpretation.

# %% [markdown]
# Getting the data from WHO site,

# %% [markdown]
# ## Visualizations
# •	Visualization (8 points, 2 points each)
# - Data visualization activity (box plot, bar plot, violin plot, and pairplot to see relationships and distribution, etc.).
# - Describe anything you find in the data after each visualization.
# - What data visualization helped you understand about data distribution.
# - What you did about possible outlier as per data distribution visualization. (Did you confirm with your client whether it is actually an outlier or put a disclosure statement in your notebook if you decided to remove it?)

# %% [markdown]
# ## Code

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('VIW_FNT.csv')

# %%
df.head()
# Out:
#   WHOREGION FLUSEASON HEMISPHERE           ITZ COUNTRY_CODE  \
# 0       AFR        NH         NH   FLU_NRT_AFR          DZA
# 1       WPR        YR         NH   FLU_SE_ASIA          KHM
# 2       EUR        NH         NH  FLU_CNT_ASIA          UZB
# 3       AMR        YR         NH   FLU_CNT_AMC          NIC
# 4       AFR        YR         NH   FLU_WST_AFR          CIV
#
#   COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK  \
# 0                Algeria        2021-11-29      2021        48
# 1               Cambodia        2015-06-15      2015        25
# 2             Uzbekistan        2017-02-13      2017         7
# 3              Nicaragua        2015-08-17      2015        34
# 4          Côte d'Ivoire        2012-10-29      2012        44
#
#   MMWR_WEEKSTARTDATE  ...  PARAINFLUENZA  RHINO  RSV  OTHERRESPVIRUS  \
# 0         2021-11-28  ...            NaN    NaN  NaN             0.0
# 1         2015-06-14  ...            NaN    NaN  NaN             NaN
# 2         2017-02-12  ...            NaN    NaN  0.0             NaN
# 3         2015-08-16  ...            NaN    NaN  NaN             NaN
# 4         2012-10-28  ...            NaN    NaN  NaN             NaN
#
#    OTHER_RESPVIRUS_DETAILS  LAB_RESULT_COMMENT  WCR_COMMENT  ISO2   ISOYW  \
# 0                      NaN                 NaN          NaN    DZ  202148
# 1                      NaN                 NaN          NaN    KH  201525
# 2                      NaN                 NaN          NaN    UZ  201707
# 3                      NaN                 NaN          NaN    NI  201534
# 4                      NaN                 NaN          NaN    CI  201244
#
#    MMWRYW
# 0  202148
# 1  201524
# 2  201707
# 3  201533
# 4  201244
#
# [5 rows x 49 columns]

# %%
df.describe()
# Out:
#             ISO_YEAR       ISO_WEEK      MMWR_YEAR      MMWR_WEEK  \
# count  139510.000000  139510.000000  139510.000000  139510.000000
# mean     2014.460469      26.030170    2014.458906      26.028980
# std         6.225484      15.780568       6.226584      15.781012
# min      1995.000000       1.000000    1995.000000       1.000000
# 25%      2011.000000      12.000000    2011.000000      12.000000
# 50%      2016.000000      25.000000    2016.000000      25.000000
# 75%      2019.000000      41.000000    2019.000000      41.000000
# max      2023.000000      53.000000    2023.000000      53.000000
#
#        SPEC_PROCESSED_NB  SPEC_RECEIVED_NB      AH1N12009            AH1  \
# count      131975.000000      48171.000000  107547.000000  100352.000000
# mean          433.060133        760.609495      13.743359       0.856216
# std          3140.042707       4816.469623     134.195792      13.073771
# min             0.000000          0.000000       0.000000       0.000000
# 25%             4.000000         11.000000       0.000000       0.000000
# 50%            25.000000         37.000000       0.000000       0.000000
# 75%            92.000000        109.000000       1.000000       0.000000
# max        187112.000000     187112.000000    9735.000000     906.000000
#
#                  AH3           AH5  ...         ADENO          BOCA  \
# count  123382.000000  42588.000000  ...  16260.000000  11212.000000
# mean       11.631494      0.009275  ...      6.326507      0.742330
# std        92.452691      0.213397  ...     18.111496      3.701205
# min         0.000000      0.000000  ...      0.000000      0.000000
# 25%         0.000000      0.000000  ...      0.000000      0.000000
# 50%         0.000000      0.000000  ...      0.000000      0.000000
# 75%         2.000000      0.000000  ...      3.000000      0.000000
# max      5498.000000     14.000000  ...    283.000000    102.000000
#
#        HUMAN_CORONA    METAPNEUMO  PARAINFLUENZA         RHINO           RSV  \
# count  10643.000000  14436.000000   16522.000000  13344.000000  62330.000000
# mean       4.891666      6.325436       9.177279     16.507494     16.357452
# std       27.855660     29.699720      34.224019     70.023304     96.718974
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        0.000000      0.000000       0.000000      0.000000      0.000000
# 50%        0.000000      0.000000       0.000000      0.000000      0.000000
# 75%        1.000000      2.000000       3.000000      5.000000      2.000000
# max      552.000000    723.000000     463.000000   1180.000000   3478.000000
#
#        OTHERRESPVIRUS          ISOYW         MMWRYW
# count    12329.000000  139510.000000  139510.000000
# mean        11.104307  201472.077048  201471.919597
# std         59.094878     622.403673     622.500179
# min          0.000000  199501.000000  199501.000000
# 25%          0.000000  201124.000000  201124.000000
# 50%          0.000000  201612.000000  201612.000000
# 75%          0.000000  201949.000000  201949.000000
# max        732.000000  202308.000000  202308.000000
#
# [8 rows x 35 columns]

# %%
ProfileReport(df)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:465, in ProfileReport._repr_html_(self)
#     463 def _repr_html_(self) -> None:
#     464     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 465     self.to_notebook_iframe()
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:445, in ProfileReport.to_notebook_iframe(self)
#     443 with warnings.catch_warnings():
#     444     warnings.simplefilter("ignore")
# --> 445     display(get_notebook_iframe(self.config, self))
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:415, in ProfileReport.to_html(self)
#     407 def to_html(self) -> str:
#     408     """Generate and return complete template as lengthy string
#     409         for using with frameworks.
#     410
#    (...)
#     413
#     414     """
# --> 415     return self.html
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:226, in ProfileReport.html(self)
#     223 @property
#     224 def html(self) -> str:
#     225     if self._html is None:
# --> 226         self._html = self._render_html()
#     227     return self._html
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:334, in ProfileReport._render_html(self)
#     331 def _render_html(self) -> str:
#     332     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 334     report = self.report
#     336     with tqdm(
#     337         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     338     ) as pbar:
#     339         html = HTMLReport(copy.deepcopy(report)).render(
#     340             nav=self.config.html.navbar_show,
#     341             offline=self.config.html.use_local_assets,
#    (...)
#     349             version=self.description_set["package"]["pandas_profiling_version"],
#     350         )
#
# File /opt/anaconda3/lib/python3.8/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py:220, in ProfileReport.report(self)
#     217 @property
#     218 def report(self) -> Root:
#     219     if self._report is None:
# --> 220         self._report = get_report_structure(self.config, self.description_set)
#     221     return self._report
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/structure/report.py:381, in get_report_structure(config, summary)
#     364 section_items: List[Renderable] = [
#     365     Container(
#     366         get_dataset_items(config, summary, alerts),
#    (...)
#     370     ),
#     371 ]
#     373 if len(summary["variables"]) > 0:
#     374     section_items.append(
#     375         Dropdown(
#     376             name="Variables",
#     377             anchor_id="variables-dropdown",
#     378             id="variables-dropdown",
#     379             items=list(summary["variables"]),
#     380             item=Container(
# --> 381                 render_variables_section(config, summary),
#     382                 sequence_type="accordion",
#     383                 name="Variables",
#     384                 anchor_id="variables",
#     385             ),
#     386         )
#     387     )
#     389 scatter_items = get_interactions(config, summary["scatter"])
#     390 if len(scatter_items) > 0:
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/structure/report.py:159, in render_variables_section(config, dataframe_summary)
#     157     variable_type = summary["type"]
#     158 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 159 template_variables.update(render_map_type(config, template_variables))
#     161 # Ignore these
#     162 if reject_variables:
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/structure/variables/render_categorical.py:411, in render_categorical(config, summary)
#     408     overview_items.append(length_table)
#     410 if characters:
# --> 411     overview_table_char, unitab = render_categorical_unicode(config, summary, varid)
#     412     overview_items.append(overview_table_char)
#     414 overview_items.append(unique_stats)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/report/structure/variables/render_categorical.py:139, in render_categorical_unicode(config, summary, varid)
#     135 cats = []
#     136 for category_alias_name, category_alias_counts in sorted(
#     137     summary["category_alias_char_counts"].items(), key=lambda x: -len(x[1])
#     138 ):
# --> 139     category_alias_name = category_alias_name.replace("_", " ")
#     140     cats.append(
#     141         FrequencyTable(
#     142             freq_table(
#    (...)
#     150         )
#     151     )
#     153 category_items = [
#     154     category_overview,
#     155     Container(
#    (...)
#     162     ),
#     163 ]
#
# AttributeError: 'NoneType' object has no attribute 'replace'
